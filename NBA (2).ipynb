# %%
import pandas as pd

# %%
df = pd.read_csv("all_seasons.csv")
df.head(10)
# Out:
#         player_name team_abbreviation  age  player_height  player_weight  \
# 0  Randy Livingston               HOU   22         193.04      94.800728
# 1  Gaylon Nickerson               WAS   28         190.50      86.182480
# 2      George Lynch               VAN   26         203.20     103.418976
# 3    George McCloud               LAL   30         203.20     102.058200
# 4      George Zidek               DEN   23         213.36     119.748288
# 5    Gerald Wilkins               ORL   33         198.12     102.058200
# 6  Gheorghe Muresan               WAS   26         231.14     137.438376
# 7         Glen Rice               CHH   30         203.20      99.790240
# 8    Glenn Robinson               MIL   24         200.66     106.594120
# 9        Grant Hill               DET   24         203.20     102.058200
#
#                  college country draft_year draft_round draft_number  ...  \
# 0        Louisiana State     USA       1996           2           42  ...
# ...

# %%
df.shape
# Out:
# (12844, 21)

# %%
df.isnull().sum()
# Out:
# player_name          0
# team_abbreviation    0
# age                  0
# player_height        0
# player_weight        0
# college              0
# country              0
# draft_year           0
# draft_round          0
# draft_number         0
# gp                   0
# pts                  0
# reb                  0
# ast                  0
# net_rating           0
# oreb_pct             0
# dreb_pct             0
# usg_pct              0
# ts_pct               0
# ast_pct              0
# season               0
# dtype: int64

# %%
(df.isnull().sum()/df.shape[0])*100
# Out:
# player_name          0.0
# team_abbreviation    0.0
# age                  0.0
# player_height        0.0
# player_weight        0.0
# college              0.0
# country              0.0
# draft_year           0.0
# draft_round          0.0
# draft_number         0.0
# gp                   0.0
# pts                  0.0
# reb                  0.0
# ast                  0.0
# net_rating           0.0
# oreb_pct             0.0
# dreb_pct             0.0
# usg_pct              0.0
# ts_pct               0.0
# ast_pct              0.0
# season               0.0
# dtype: float64

# %%
(df.isnull().sum().sum()/(df.shape[0] * df.shape[1]))*100
# Out:
# np.float64(0.0)

# %%
df["college"].mode()[0]
# Out:
# 'Kentucky'

# %%
df.fillna({"college": df["college"].mode()[0]}, inplace=True)

# %%
df.head(5)
# Out:
#         player_name team_abbreviation  age  player_height  player_weight  \
# 0  Randy Livingston               HOU   22         193.04      94.800728
# 1  Gaylon Nickerson               WAS   28         190.50      86.182480
# 2      George Lynch               VAN   26         203.20     103.418976
# 3    George McCloud               LAL   30         203.20     102.058200
# 4      George Zidek               DEN   23         213.36     119.748288
#
#                  college country draft_year draft_round draft_number  ...  \
# 0        Louisiana State     USA       1996           2           42  ...
# 1  Northwestern Oklahoma     USA       1994           2           34  ...
# 2         North Carolina     USA       1993           1           12  ...
# 3          Florida State     USA       1989           1            7  ...
# 4                   UCLA     USA       1995           1           22  ...
#
#     pts  reb  ast  net_rating  oreb_pct  dreb_pct  usg_pct  ts_pct  ast_pct  \
# ...

# %%
df.to_csv("all_seasons.csv", index = False)

# %%
df.head(10)
# Out:
#         player_name team_abbreviation  age  player_height  player_weight  \
# 0  Randy Livingston               HOU   22         193.04      94.800728
# 1  Gaylon Nickerson               WAS   28         190.50      86.182480
# 2      George Lynch               VAN   26         203.20     103.418976
# 3    George McCloud               LAL   30         203.20     102.058200
# 4      George Zidek               DEN   23         213.36     119.748288
# 5    Gerald Wilkins               ORL   33         198.12     102.058200
# 6  Gheorghe Muresan               WAS   26         231.14     137.438376
# 7         Glen Rice               CHH   30         203.20      99.790240
# 8    Glenn Robinson               MIL   24         200.66     106.594120
# 9        Grant Hill               DET   24         203.20     102.058200
#
#                  college country draft_year draft_round draft_number  ...  \
# 0        Louisiana State     USA       1996           2           42  ...
# ...

# %%
col = pd.DataFrame(df.columns)
col
# Out:
#                     0
# 0         player_name
# 1   team_abbreviation
# 2                 age
# 3       player_height
# 4       player_weight
# 5             college
# 6             country
# 7          draft_year
# 8         draft_round
# 9        draft_number
# 10                 gp
# 11                pts
# 12                reb
# 13                ast
# 14         net_rating
# 15           oreb_pct
# 16           dreb_pct
# 17            usg_pct
# 18             ts_pct
# 19            ast_pct
# 20             season

# %%
df.head()

# %%
df.to_csv("all_seasons.csv", index=False)

# %%
pip install sqlalchemy pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sqlalchemy import create_engine
import pandas as pd

# Replace with your MySQL credentials
username = 'root'
password = 'MySQLsiva2003'
host = 'localhost:3306'
database = 'NBA'

# Create the connection URL
connection_url = f'mysql+pymysql://{username}:{password}@{host}/{database}'

try:
    # Create an SQLAlchemy engine
    engine = create_engine(connection_url)
    print("Connected to the database successfully.")

    # Create a DataFrame to upload
    accounts_df = pd.read_csv('all_seasons.csv')
    print("CSV file loaded successfully.")

    # Upload the DataFrame to MySQL
    accounts_df.to_sql('nba_basketball', con=engine, if_exists='replace', index=False)
    print("Data uploaded successfully.")

except Exception as e:
    print("An error occurred:", e)
# Out:
# Connected to the database successfully.
# CSV file loaded successfully.
# Data uploaded successfully.

# %%
pip install
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
